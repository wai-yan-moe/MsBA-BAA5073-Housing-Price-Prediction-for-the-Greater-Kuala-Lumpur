# %% [markdown]
# # 02 - EDA: Distributions
#
# Univariate analysis of the target variable, structural features, distance features, and categorical features.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
from src.eda import load_eda_data

df = load_eda_data()
print(f"{len(df):,} rows loaded")

# %% [markdown]
# ## Target Variable Distribution
#
# The raw price is heavily right-skewed. A log transform brings it close to normal, which benefits regression models.

# %%
from src.eda import plot_target_distribution

plot_target_distribution(df)

# %%
from IPython.display import Image
Image(filename=str(project_root / 'outputs' / 'figures' / '01_target_distribution.png'), width=900)

# %% [markdown]
# ## Structural Feature Distributions

# %%
from src.eda import plot_numerical_distributions

plot_numerical_distributions(df)

# %%
Image(filename=str(project_root / 'outputs' / 'figures' / '02_structural_distributions.png'), width=900)

# %%
Image(filename=str(project_root / 'outputs' / 'figures' / '03_distance_distributions.png'), width=900)

# %% [markdown]
# ## Categorical Feature Distributions

# %%
from src.eda import plot_categorical_distributions

plot_categorical_distributions(df)

# %%
Image(filename=str(project_root / 'outputs' / 'figures' / '04_categorical_distributions.png'), width=900)

# %% [markdown]
# ## Quick Summary Statistics

# %%
num_cols = ['Price', 'Price_Log', 'Built_up_sqft', 'Land_Area_sqft',
            'Rooms', 'Bathrooms', 'Car_Parks']
df[num_cols].describe().round(2)
